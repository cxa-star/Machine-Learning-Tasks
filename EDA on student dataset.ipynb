# %% [markdown]
# #TASK-14,15,18.19,20

# %%
import pandas as pd

# %%
df = pd.read_csv("Student_Performance (1).csv")

# %%
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
df.drop_duplicates(df)
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
df.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# ...

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #TASK-19  Scatter Plot Relationship Analysis

# %%
plt.scatter(df["Hours Studied"],df["Performance Index"])
plt.xlabel("Hours Studied")
plt.ylabel("Performance Index")
plt.title("Hours StudiedvsPerformance Index")
plt.show()

# %%
plt.scatter(df["Previous Scores"],df["Performance Index"])
plt.xlabel("Previous Scores")
plt.ylabel("Performance Index")
plt.title("Previous ScoresvsPerformance Index")
plt.show()

# %%
plt.scatter(df["Sleep Hours"],df["Performance Index"])
plt.xlabel("Sleep Hours")
plt.ylabel("Performance Index")
plt.title("Sleep HoursvsPerformance Index")
plt.show()

# %%
plt.scatter(df["Sample Question Papers Practiced"],df["Performance Index"])
plt.xlabel("Sample Question Papers Practiced")
plt.ylabel("Performance Index")
plt.title("Sample Question Papers PracticedvsPerformance Index")
plt.show()

# %%
plt.scatter(df["Sample Question Papers Practiced"],df["Hours Studied"])
plt.xlabel("Sample Question Papers Practiced")
plt.ylabel("Hours Studied")
plt.title("Sample Question Papers PracticedvsPerformance Index")
plt.show()

# %%
plt.figure()
plt.hist(df["Performance Index"])
plt.xlabel("Performance Index")
plt.ylabel("Frequency")
plt.show()

# %%
print("Average:", df["Performance Index"].mean())
print("Maximum:", df["Performance Index"].max())
print("Minimum:", df["Performance Index"].min())
# Out:
# Average: 55.2248
# Maximum: 100.0
# Minimum: 10.0

# %% [markdown]
# #TASK-14  Exploratory Data Analysis (EDA) on Student Dataset

# %%
corr = df.corr(numeric_only=True)

corr
# Out:
#                                   Hours Studied  Previous Scores  Sleep Hours  \
# Hours Studied                          1.000000        -0.012390     0.001245
# Previous Scores                       -0.012390         1.000000     0.005944
# Sleep Hours                            0.001245         0.005944     1.000000
# Sample Question Papers Practiced       0.017463         0.007888     0.003990
# Performance Index                      0.373730         0.915189     0.048106
#
#                                   Sample Question Papers Practiced  \
# Hours Studied                                             0.017463
# Previous Scores                                           0.007888
# Sleep Hours                                               0.003990
# Sample Question Papers Practiced                          1.000000
# Performance Index                                         0.043268
#
#                                   Performance Index
# ...

# %%
corr = df.corr(numeric_only=True)
corr["Performance Index"].sort_values().plot(kind="bar")
plt.xlabel("Features")
plt.ylabel("Correlation")
plt.title("Feature Correlation Analysis")
plt.show()

# %% [markdown]
# #TASK-18   Student Performance Index Prediction

# %%
df.dtypes
# Out:
# Hours Studied                         int64
# Previous Scores                       int64
# Extracurricular Activities              str
# Sleep Hours                           int64
# Sample Question Papers Practiced      int64
# Performance Index                   float64
# dtype: object

# %%
df["Extracurricular Activities"].unique()
# Out:
# <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str

# %%
df["Extracurricular Activities"]=df["Extracurricular Activities"].map({
    "Yes":1,
    "No":0
})

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              7               99                           1            9
# 1              4               82                           0            4
# 2              8               51                           1            7
# 3              5               52                           1            5
# 4              7               75                           0            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
x=df.drop("Performance Index",axis=1)

# %%
y=df["Performance Index"]

# %%
y.head()
# Out:
# 0    91.0
# 1    65.0
# 2    45.0
# 3    36.0
# 4    66.0
# Name: Performance Index, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x.head()
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              7               99                           1            9
# 1              4               82                           0            4
# 2              8               51                           1            7
# 3              5               52                           1            5
# 4              7               75                           0            8
#
#    Sample Question Papers Practiced
# 0                                 1
# 1                                 2
# 2                                 2
# 3                                 2
# 4                                 5

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train.shape)
# Out:
# (8000, 5)

# %%
print(y_train.shape)
# Out:
# (8000,)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([2.85248393, 1.0169882 , 0.60861668, 0.47694148, 0.19183144])

# %%
y_predict=model.predict(x_test)

# %%
y_predict
# Out:
# array([54.71185392, 22.61551294, 47.90314471, ..., 16.79341955,
#        63.34327368, 45.94262301], shape=(2000,))

# %%
comparison=pd.DataFrame({
    "Actual":y_test,
    "predicted":y_predict

    
})

# %%
comparison
# Out:
#       Actual  predicted
# 6252    51.0  54.711854
# 4684    20.0  22.615513
# 1731    46.0  47.903145
# 4742    28.0  31.289767
# 4521    41.0  43.004570
# ...      ...        ...
# 6412    45.0  46.886280
# 8285    66.0  62.698025
# 7853    16.0  16.793420
# 1095    65.0  63.343274
# 6929    47.0  45.942623
#
# [2000 rows x 2 columns]

# %% [markdown]
# #TASK-20  Feature Selection Challenge

# %%
corr = df.corr(numeric_only=True)
print(corr["Performance Index"].sort_values(ascending=False))
# Out:
# Performance Index                   1.000000
# Previous Scores                     0.915189
# Hours Studied                       0.373730
# Sleep Hours                         0.048106
# Sample Question Papers Practiced    0.043268
# Extracurricular Activities          0.024525
# Name: Performance Index, dtype: float64

# %%
corr["Performance Index"].sort_values().plot(kind="bar")
plt.xlabel("Features")
plt.ylabel("Correlation")
plt.title("Feature Selection Based on Correlation")
plt.show()
